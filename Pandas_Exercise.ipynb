# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pandas import Series, DataFrame
import pandas as pd
import numpy as np
from numpy import nan as NaN

# %%
data ={'Location': ['United States','India','Brazil','Russia','United Kingdom','Fraance','Spain','Italy','Turkey','Germany'], 'Cases': [28833039,11079979,10517232,4246079,4170519,3736016,3188553,2907825,2693164,2444169],'Deaths':[517204,156938,254263,86122,122705,86332,69142,97507,28503,70601],'Recovered':[NaN,10763451,9386440,3811797,NaN,NaN,NaN,2398352,2565723,2242767]}
obj = Series(data)
print(obj)
df = DataFrame(data)
df
# Out:
# Location     [United States, India, Brazil, Russia, United ...
# Cases        [28833039, 11079979, 10517232, 4246079, 417051...
# Deaths       [517204, 156938, 254263, 86122, 122705, 86332,...
# Recovered    [nan, 10763451, 9386440, 3811797, nan, nan, na...
# dtype: object
#          Location     Cases  Deaths   Recovered
# 0   United States  28833039  517204         NaN
# 1           India  11079979  156938  10763451.0
# 2          Brazil  10517232  254263   9386440.0
# 3          Russia   4246079   86122   3811797.0
# 4  United Kingdom   4170519  122705         NaN
# 5         Fraance   3736016   86332         NaN
# 6           Spain   3188553   69142         NaN
# 7           Italy   2907825   97507   2398352.0
# 8          Turkey   2693164   28503   2565723.0
# 9         Germany   2444169   70601   2242767.0

# %%
# df['Status']= df.Cases
df2 = DataFrame(data, columns = ['Location','Cases','Deaths','Recovered','Status'])
df2
# Out:
#          Location     Cases  Deaths   Recovered  Status  Deaths_Rank
# 0   United States  28833039  517204         NaN    High         10.0
# 1           India  11079979  156938  10763451.0    High          8.0
# 2          Brazil  10517232  254263   9386440.0    High          9.0
# 3          Russia   4246079   86122   3811797.0    High          4.0
# 4  United Kingdom   4170519  122705         NaN    High          7.0
# 5         Fraance   3736016   86332         NaN  Medium          5.0
# 6           Spain   3188553   69142         NaN  Medium          2.0
# 7           Italy   2907825   97507   2398352.0  Medium          6.0
# 8          Turkey   2693164   28503   2565723.0  Medium          1.0
# 9         Germany   2444169   70601   2242767.0  Medium          3.0

# %%
df2.loc[df['Cases'] < 3000000, 'Status'] = 'Low'
df2.loc[df['Cases'] < 4000000, 'Status'] = 'Medium'
df2.loc[df['Cases'] > 4000000, 'Status'] = 'High'


df2
# Out:
#          Location     Cases  Deaths   Recovered  Status  Deaths_Rank
# 0   United States  28833039  517204         NaN    High         10.0
# 1           India  11079979  156938  10763451.0    High          8.0
# 2          Brazil  10517232  254263   9386440.0    High          9.0
# 3          Russia   4246079   86122   3811797.0    High          4.0
# 4  United Kingdom   4170519  122705         NaN    High          7.0
# 5         Fraance   3736016   86332         NaN  Medium          5.0
# 6           Spain   3188553   69142         NaN  Medium          2.0
# 7           Italy   2907825   97507   2398352.0  Medium          6.0
# 8          Turkey   2693164   28503   2565723.0  Medium          1.0
# 9         Germany   2444169   70601   2242767.0  Medium          3.0
